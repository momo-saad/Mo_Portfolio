# %% [markdown]
# # Data Loading and Initial Exploration

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset into a DataFrame
df = pd.read_excel(r"C:\Users\DELL\OneDrive\Desktop\projects\Python Projects\Project 1\order dataset.xlsx")

# %%
# Display the first few rows to understand the data
df.head()
# Out:
#   Order No Order Date  Order Year    Customer Name  \
# 0   5014-1 2013-02-11        2013    Patrick Jones
# 1   5016-1 2013-02-11        2013     Alex Russell
# 2   5018-1 2013-02-12        2013    Tamara Dahlen
# 3   5019-1 2013-02-13        2013  Susan Vittorini
# 4   5020-1 2013-02-14        2013  Muhammed Yedwab
#
#                        Address       City State Customer Type  \
# 0       221 Barkly St,St Kilda  Melbourne   VIC   Home Office
# 1   101/12 Victoria Ave, Perth  Melbourne   VIC   Home Office
# 2            61 York St,Sydney     Sydney   NSW     Corporate
# 3  3 Carrington Road ,Box Hill  Melbourne   VIC   Home Office
# 4        18 Whistler St,Sydney     Sydney   NSW      Consumer
#
#       Account Manager Order Priority  ... Cost Price Retail Price  \
# 0         Yvette Biti           High  ...       3.52         5.58
# 1        Connor Betts           High  ...       2.39         4.26
# 2    Leighton Forrest       Critical  ...       2.41         3.71
# ...

# %%
# Display basic information about the DataFrame (column names, data types, etc.)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1039 entries, 0 to 1038
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Order No           1039 non-null   object
#  1   Order Date         1039 non-null   datetime64[ns]
#  2   Order Year         1039 non-null   int64
#  3   Customer Name      1039 non-null   object
#  4   Address            1039 non-null   object
#  5   City               1039 non-null   object
#  6   State              1039 non-null   object
#  7   Customer Type      1039 non-null   object
#  8   Account Manager    1039 non-null   object
#  9   Order Priority     1037 non-null   object
#  10  Product Name       1039 non-null   object
#  11  Product Category   1039 non-null   object
#  12  Product Container  1039 non-null   object
#  13  Ship Mode          1039 non-null   object
#  14  Ship Date          1037 non-null   datetime64[ns]
# ...

# %%
# Describe the dataset to get basic statistics
df.describe()
# Out:
#         Order Year   Cost Price  Retail Price  Profit Margin  Order Quantity  \
# count  1039.000000  1039.000000   1039.000000    1039.000000     1039.000000
# mean   2014.652551    23.879249     45.669485      21.790236       26.044273
# std       1.150342    59.587211    104.986700      47.980607       14.738503
# min    2013.000000     0.240000      1.140000       0.355300        1.000000
# 25%    2014.000000     1.940000      3.520000       1.400000       13.000000
# 50%    2015.000000     3.750000      7.280000       3.180000       26.000000
# 75%    2016.000000    13.880000     28.140000      13.590000       39.000000
# max    2017.000000   377.990000    599.990000     316.030000       50.000000
#
#           Sub Total   Discount %   Discount $   Order Total  Shipping Cost  \
# count   1039.000000  1039.000000  1039.000000   1039.000000    1039.000000
# mean    1154.193597     0.051357    64.212510   1089.981087       6.079480
# ...

# %% [markdown]
# # Data Cleaning

# %%
# Check for missing values
print(df.isnull().sum())
# Out:
# Order No             0
# Order Date           0
# Order Year           0
# Customer Name        0
# Address              0
# City                 0
# State                0
# Customer Type        0
# Account Manager      0
# Order Priority       2
# Product Name         0
# Product Category     0
# Product Container    0
# Ship Mode            0
# Ship Date            2
# Cost Price           0
# Retail Price         0
# Profit Margin        0
# Order Quantity       0
# Sub Total            0
# Discount %           0
# Discount $           0
# Order Total          0
# Shipping Cost        0
# Total                0
# dtype: int64

# %%
# Remove rows with significant missing values or fill with appropriate values
df.dropna(inplace=True)

# %%
print(df.isnull().sum())
# Out:
# Order No             0
# Order Date           0
# Order Year           0
# Customer Name        0
# Address              0
# City                 0
# State                0
# Customer Type        0
# Account Manager      0
# Order Priority       0
# Product Name         0
# Product Category     0
# Product Container    0
# Ship Mode            0
# Ship Date            0
# Cost Price           0
# Retail Price         0
# Profit Margin        0
# Order Quantity       0
# Sub Total            0
# Discount %           0
# Discount $           0
# Order Total          0
# Shipping Cost        0
# Total                0
# dtype: int64

# %%
# Check for duplicates and remove them
df.drop_duplicates(inplace=True)

# %%
# Convert 'Order Date' to datetime
df['Order Date'] = pd.to_datetime(df['Order Date'])

# %%
# Convert numeric columns to appropriate types
numeric_column = ['Order Quantity']
df[numeric_column] = df[numeric_column].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1035 entries, 0 to 1036
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Order No           1035 non-null   object
#  1   Order Date         1035 non-null   datetime64[ns]
#  2   Order Year         1035 non-null   int64
#  3   Customer Name      1035 non-null   object
#  4   Address            1035 non-null   object
#  5   City               1035 non-null   object
#  6   State              1035 non-null   object
#  7   Customer Type      1035 non-null   object
#  8   Account Manager    1035 non-null   object
#  9   Order Priority     1035 non-null   object
#  10  Product Name       1035 non-null   object
#  11  Product Category   1035 non-null   object
#  12  Product Container  1035 non-null   object
#  13  Ship Mode          1035 non-null   object
#  14  Ship Date          1035 non-null   datetime64[ns]
# ...

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
# Plot distribution of 'Order Year' to understand the time span of the data
sns.histplot(df['Order Year'], kde=True)
plt.title("Distribution of Order Year")
plt.show()

# %%
# Visualize sales trends over time
df.groupby('Order Year')['Order Total'].sum().plot(kind='line')
plt.title("Total Sales Over the Years")
plt.xlabel("Year")
plt.ylabel("Total Sales $")
plt.show()

# %%
# Analyze sales by customer type
sns.barplot(x='Customer Type', y='Order Total', data=df)
plt.title("Sales by Customer Type")
plt.show()

# %%
# Analyze order quantity by product category
sns.boxplot(x='Product Category', y='Order Quantity', data=df)
plt.title("Order Quantity by Product Category")
plt.show()

# %% [markdown]
# # Data Analysis

# %%
# Correlation analysis
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()

# %%
# Identify top-selling products
top_products = df.groupby('Product Name')['Order Total'].sum().sort_values(ascending=False).head(5)
top_products.plot(kind='barh')
plt.title("Top 5-Selling Products")
plt.show()

# %%
# Analyze profit margins
sns.histplot(df['Profit Margin'], kde=True)
plt.title("Distribution of Profit Margins")
plt.show()

# %%
# Analyze shipping costs by state
sns.barplot(x='State', y='Shipping Cost', data=df)
plt.title("Shipping Cost by State")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Order Analysis

# %%
# Order frequency over the years
order_freq_by_year = df.groupby('Order Year')['Order No'].count()
order_freq_by_year.plot(kind='bar')
plt.title("Order Frequency Over the Years")
plt.xlabel("Order Year")
plt.ylabel("Number of Orders")
plt.show()

# %%
# Order priority distribution
sns.countplot(x='Order Priority', data=df)
plt.title("Order Priority Distribution")
plt.show()

# %%
# Shipping mode distribution
sns.countplot(x='Ship Mode', data=df)
plt.title("Shipping Mode Distribution")
plt.show()

# %% [markdown]
# # Discount Analysis

# %%
# Distribution of discount percentages
sns.histplot(df['Discount %'], kde=True)
plt.title("Distribution of Discount Percentages")
plt.show()

# %%
# Relationship between discounts and order total
sns.scatterplot(x='Discount %', y='Order Total', data=df)
plt.title("Discount % vs. Order Total")
plt.show()

# %%
# Top products with the highest discounts
top_discounted_products = df.groupby('Product Name')['Discount $'].sum().sort_values(ascending=False).head(10)
top_discounted_products.plot(kind='barh')
plt.title("Top Products by Discount Value")
plt.show()
